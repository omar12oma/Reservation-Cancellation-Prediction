# %%
import pandas as pd

# %%
df=pd.read_csv("train__dataset.csv")

# %%
df.shape
# Out:
# (18137, 18)

# %%
a=df['booking_status'].sum()

# %%
b=df['booking_status'].count()

# %%
a/b
# Out:
# 0.3276175773281138

# %%
from sklearn.linear_model import LinearRegression

# %%
df.isna().sum()
# Out:
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
X=df.drop(columns=['booking_status'])

# %%
y=df['booking_status']

# %%
X.shape
# Out:
# (18137, 17)

# %%
y.shape
# Out:
# (18137,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log=LogisticRegression()
log.fit(X,y)
# Out:
# c:\Users\OMARS\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
yd=log.predict(X)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(yd,y)
# Out:
# 0.7834261454485306

# %%
import seaborn as sns

# %%
corr=df.corr()

# %%
corr
# Out:
#                                       no_of_adults  no_of_children  \
# no_of_adults                              1.000000       -0.017565
# no_of_children                           -0.017565        1.000000
# no_of_weekend_nights                      0.098241        0.026761
# no_of_week_nights                         0.103135        0.018957
# type_of_meal_plan                         0.025139       -0.066445
# required_car_parking_space                0.010956        0.026409
# room_type_reserved                        0.163542        0.484223
# lead_time                                 0.098254       -0.051646
# arrival_year                              0.077915        0.044164
# arrival_month                             0.018254        0.008244
# arrival_date                              0.028433        0.020804
# market_segment_type                      -0.098518        0.078264
# repeated_guest                           -0.198334       -0.037868
# no_of_previous_cancellations             -0.043494       -0.015580
# no_of_previous_bookings_not_canceled     -0.119703       -0.021495
# avg_price_per_room                        0.292910        0.342425
# no_of_special_requests                    0.179970        0.128325
# booking_status                            0.094354        0.035093
#
#                                       no_of_weekend_nights  no_of_week_nights  \
# no_of_adults                                      0.098241           0.103135
# no_of_children                                    0.026761           0.018957
# no_of_weekend_nights                              1.000000           0.188796
# no_of_week_nights                                 0.188796           1.000000
# type_of_meal_plan                                -0.048357          -0.076067
# required_car_parking_space                       -0.029054          -0.054087
# room_type_reserved                                0.044741           0.066756
# lead_time                                         0.047559           0.148348
# arrival_year                                      0.054914           0.037240
# arrival_month                                    -0.010060           0.044170
# arrival_date                                      0.024026          -0.007471
# market_segment_type                              -0.011626          -0.060650
# repeated_guest                                   -0.058549          -0.094936
# no_of_previous_cancellations                     -0.015543          -0.024761
# no_of_previous_bookings_not_canceled             -0.018829          -0.041108
# avg_price_per_room                               -0.005837           0.029326
# no_of_special_requests                            0.057814           0.037413
# booking_status                                    0.061117           0.096472
#
#                                       type_of_meal_plan  \
# no_of_adults                                   0.025139
# no_of_children                                -0.066445
# no_of_weekend_nights                          -0.048357
# no_of_week_nights                             -0.076067
# type_of_meal_plan                              1.000000
# required_car_parking_space                    -0.021426
# room_type_reserved                            -0.146645
# lead_time                                      0.134350
# arrival_year                                  -0.083469
# arrival_month                                  0.019607
# arrival_date                                   0.019243
# market_segment_type                           -0.156242
# repeated_guest                                -0.068313
# no_of_previous_cancellations                  -0.018854
# no_of_previous_bookings_not_canceled          -0.042258
# avg_price_per_room                             0.039359
# no_of_special_requests                        -0.054258
# booking_status                                 0.076685
#
#                                       required_car_parking_space  \
# no_of_adults                                            0.010956
# no_of_children                                          0.026409
# no_of_weekend_nights                                   -0.029054
# no_of_week_nights                                      -0.054087
# type_of_meal_plan                                      -0.021426
# required_car_parking_space                              1.000000
# room_type_reserved                                      0.031255
# lead_time                                              -0.076608
# arrival_year                                            0.006502
# arrival_month                                          -0.018159
# arrival_date                                           -0.008735
# market_segment_type                                     0.109336
# repeated_guest                                          0.116001
# no_of_previous_cancellations                            0.027336
# no_of_previous_bookings_not_canceled                    0.062674
# avg_price_per_room                                      0.062199
# no_of_special_requests                                  0.083360
# booking_status                                         -0.092640
#
#                                       room_type_reserved  lead_time  \
# no_of_adults                                    0.163542   0.098254
# no_of_children                                  0.484223  -0.051646
# no_of_weekend_nights                            0.044741   0.047559
# no_of_week_nights                               0.066756   0.148348
# type_of_meal_plan                              -0.146645   0.134350
# required_car_parking_space                      0.031255  -0.076608
# room_type_reserved                              1.000000  -0.088265
# lead_time                                      -0.088265   1.000000
# arrival_year                                    0.073680   0.148482
# arrival_month                                   0.003517   0.140062
# arrival_date                                    0.030617   0.012856
# market_segment_type                             0.165417  -0.312090
# repeated_guest                                 -0.006948  -0.135079
# no_of_previous_cancellations                   -0.001362  -0.042747
# no_of_previous_bookings_not_canceled           -0.001447  -0.078664
# avg_price_per_room                              0.411577  -0.069985
# no_of_special_requests                          0.121888  -0.103707
# booking_status                                  0.021723   0.434314
#
#                                       arrival_year  arrival_month  \
# no_of_adults                              0.077915       0.018254
# no_of_children                            0.044164       0.008244
# no_of_weekend_nights                      0.054914      -0.010060
# no_of_week_nights                         0.037240       0.044170
# type_of_meal_plan                        -0.083469       0.019607
# required_car_parking_space                0.006502      -0.018159
# room_type_reserved                        0.073680       0.003517
# lead_time                                 0.148482       0.140062
# arrival_year                              1.000000      -0.343696
# arrival_month                            -0.343696       1.000000
# arrival_date                              0.008437      -0.034861
# market_segment_type                       0.083831      -0.038777
# repeated_guest                           -0.018765      -0.004458
# no_of_previous_cancellations              0.006593      -0.040632
# no_of_previous_bookings_not_canceled      0.025689      -0.015225
# avg_price_per_room                        0.184786       0.053381
# no_of_special_requests                    0.048557       0.103389
# booking_status                            0.183256      -0.011472
#
#                                       arrival_date  market_segment_type  \
# no_of_adults                              0.028433            -0.098518
# no_of_children                            0.020804             0.078264
# no_of_weekend_nights                      0.024026            -0.011626
# no_of_week_nights                        -0.007471            -0.060650
# type_of_meal_plan                         0.019243            -0.156242
# required_car_parking_space               -0.008735             0.109336
# room_type_reserved                        0.030617             0.165417
# lead_time                                 0.012856            -0.312090
# arrival_year                              0.008437             0.083831
# arrival_month                            -0.034861            -0.038777
# arrival_date                              1.000000             0.006799
# market_segment_type                       0.006799             1.000000
# repeated_guest                           -0.010958             0.304650
# no_of_previous_cancellations             -0.011854             0.071473
# no_of_previous_bookings_not_canceled     -0.005799             0.201586
# avg_price_per_room                        0.009419            -0.044086
# no_of_special_requests                    0.025031             0.203076
# booking_status                            0.011389            -0.045906
#
#                                       repeated_guest  \
# no_of_adults                               -0.198334
# no_of_children                             -0.037868
# no_of_weekend_nights                       -0.058549
# no_of_week_nights                          -0.094936
# type_of_meal_plan                          -0.068313
# required_car_parking_space                  0.116001
# room_type_reserved                         -0.006948
# lead_time                                  -0.135079
# arrival_year                               -0.018765
# arrival_month                              -0.004458
# arrival_date                               -0.010958
# market_segment_type                         0.304650
# repeated_guest                              1.000000
# no_of_previous_cancellations                0.378014
# no_of_previous_bookings_not_canceled        0.550633
# avg_price_per_room                         -0.173846
# no_of_special_requests                     -0.016543
# booking_status                             -0.106715
#
#                                       no_of_previous_cancellations  \
# no_of_adults                                             -0.043494
# no_of_children                                           -0.015580
# no_of_weekend_nights                                     -0.015543
# no_of_week_nights                                        -0.024761
# type_of_meal_plan                                        -0.018854
# required_car_parking_space                                0.027336
# room_type_reserved                                       -0.001362
# lead_time                                                -0.042747
# arrival_year                                              0.006593
# arrival_month                                            -0.040632
# arrival_date                                             -0.011854
# market_segment_type                                       0.071473
# repeated_guest                                            0.378014
# no_of_previous_cancellations                              1.000000
# no_of_previous_bookings_not_canceled                      0.459753
# avg_price_per_room                                       -0.060170
# no_of_special_requests                                   -0.007059
# booking_status                                           -0.031852
#
#                                       no_of_previous_bookings_not_canceled  \
# no_of_adults                                                     -0.119703
# no_of_children                                                   -0.021495
# no_of_weekend_nights                                             -0.018829
# no_of_week_nights                                                -0.041108
# type_of_meal_plan                                                -0.042258
# required_car_parking_space                                        0.062674
# room_type_reserved                                               -0.001447
# lead_time                                                        -0.078664
# arrival_year                                                      0.025689
# arrival_month                                                    -0.015225
# arrival_date                                                     -0.005799
# market_segment_type                                               0.201586
# repeated_guest                                                    0.550633
# no_of_previous_cancellations                                      0.459753
# no_of_previous_bookings_not_canceled                              1.000000
# avg_price_per_room                                               -0.114968
# no_of_special_requests                                            0.014382
# booking_status                                                   -0.060697
#
#                                       avg_price_per_room  \
# no_of_adults                                    0.292910
# no_of_children                                  0.342425
# no_of_weekend_nights                           -0.005837
# no_of_week_nights                               0.029326
# type_of_meal_plan                               0.039359
# required_car_parking_space                      0.062199
# room_type_reserved                              0.411577
# lead_time                                      -0.069985
# arrival_year                                    0.184786
# arrival_month                                   0.053381
# arrival_date                                    0.009419
# market_segment_type                            -0.044086
# repeated_guest                                 -0.173846
# no_of_previous_cancellations                   -0.060170
# no_of_previous_bookings_not_canceled           -0.114968
# avg_price_per_room                              1.000000
# no_of_special_requests                          0.185245
# booking_status                                  0.145245
#
#                                       no_of_special_requests  booking_status
# no_of_adults                                        0.179970        0.094354
# no_of_children                                      0.128325        0.035093
# no_of_weekend_nights                                0.057814        0.061117
# no_of_week_nights                                   0.037413        0.096472
# type_of_meal_plan                                  -0.054258        0.076685
# required_car_parking_space                          0.083360       -0.092640
# room_type_reserved                                  0.121888        0.021723
# lead_time                                          -0.103707        0.434314
# arrival_year                                        0.048557        0.183256
# arrival_month                                       0.103389       -0.011472
# arrival_date                                        0.025031        0.011389
# market_segment_type                                 0.203076       -0.045906
# repeated_guest                                     -0.016543       -0.106715
# no_of_previous_cancellations                       -0.007059       -0.031852
# no_of_previous_bookings_not_canceled                0.014382       -0.060697
# avg_price_per_room                                  0.185245        0.145245
# no_of_special_requests                              1.000000       -0.248289
# booking_status                                     -0.248289        1.000000

# %%
sns.color_palette("tab10")
sns.set(rc={'figure.figsize':(35,35)})
sns.heatmap(corr, annot=True,cmap="Blues",
        xticklabels=corr.columns,
        yticklabels=corr.columns)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18137 entries, 0 to 18136
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   no_of_adults                          18137 non-null  int64
#  1   no_of_children                        18137 non-null  int64
#  2   no_of_weekend_nights                  18137 non-null  int64
#  3   no_of_week_nights                     18137 non-null  int64
#  4   type_of_meal_plan                     18137 non-null  int64
#  5   required_car_parking_space            18137 non-null  int64
#  6   room_type_reserved                    18137 non-null  int64
#  7   lead_time                             18137 non-null  int64
#  8   arrival_year                          18137 non-null  int64
#  9   arrival_month                         18137 non-null  int64
#  10  arrival_date                          18137 non-null  int64
#  11  market_segment_type                   18137 non-null  int64
#  12  repeated_guest                        18137 non-null  int64
#  13  no_of_previous_cancellations          18137 non-null  int64
#  14  no_of_previous_bookings_not_canceled  18137 non-null  int64
#  15  avg_price_per_room                    18137 non-null  float64
#  16  no_of_special_requests                18137 non-null  int64
#  17  booking_status                        18137 non-null  int64
# dtypes: float64(1), int64(17)
# memory usage: 2.5 MB

# %%
sns.boxplot(data=df )
sns.set(rc={'figure.figsize':(35,35)})

# %% [markdown]
# ###
